# %%
import numpy as np
import pandas as pd
import csv

# %%
# Importing the dataset
df = pd.read_csv('OnlineNewsPopularity.csv')

# remove left space from column headers
df.columns = df.columns.str.replace(' ', '')

# drop non-predictive items
df=df.drop(['url', 'timedelta'], axis=1)

# replace shares count with "Viral" class
df.loc[df.shares >= 10000, 'Viral'] = 'True' 
df.loc[df.shares < 10000, 'Viral'] = 'False' 
df=df.drop(['shares'], axis=1)

df.head()
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0              12               219         0.663594               1.0
# 1               9               255         0.604743               1.0
# 2               9               211         0.575130               1.0
# 3               9               531         0.503788               1.0
# 4              13              1072         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.815385          4               2         1           0
# 1                  0.791946          3               1         1           0
# 2                  0.663866          3               1         1           0
# 3                  0.665635          9               0         1           0
# 4                  0.540890         19              19        20           0
#
# ...

# %%
#separate variables into X (independents) and Y (dependent)
X = []
y= []
X = df.iloc[:, :57]
y = df.iloc[:, 58]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(tol=0.1, solver='saga') #'tol' and 'sag' optimizes for multivariate

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='saga', tol=0.1,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9421835059868156
# Testing Data Score: 0.9420845525174049

# %%
target_names = ["not viral", "viral"]

# Calculate classification report
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#   not viral       0.94      1.00      0.97      9359
#       viral       0.11      0.01      0.01       552
#
# avg / total       0.90      0.94      0.92      9911
