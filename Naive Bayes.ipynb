# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importing the dataset
df = pd.read_csv('OnlineNewsPopularity.csv')

# remove left space from column headers
df.columns = df.columns.str.replace(' ', '')

#drop non-predictive items
df=df.drop(['url', 'timedelta'], axis=1)

#drop negative values for Naive Bayes
df=df.drop(['kw_min_min', 
           'kw_avg_min',
           'kw_min_avg',
           'global_sentiment_polarity',
           'avg_negative_polarity',
           'min_negative_polarity',
           'max_negative_polarity',
           'title_sentiment_polarity',], axis=1)


# replace shares count with dummy class
df.loc[df.shares >= 10000, 'Viral'] = 1
df.loc[df.shares < 10000, 'Viral'] = 0 
df=df.drop(['shares'], axis=1)

df.head()
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0              12               219         0.663594               1.0
# 1               9               255         0.604743               1.0
# 2               9               211         0.575130               1.0
# 3               9               531         0.503788               1.0
# 4              13              1072         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.815385          4               2         1           0
# 1                  0.791946          3               1         1           0
# 2                  0.663866          3               1         1           0
# 3                  0.665635          9               0         1           0
# 4                  0.540890         19              19        20           0
#
#    average_token_length  ...    global_rate_negative_words  \
# ...

# %%
X = []
y= []
X = df.iloc[:, :49]
y = df.iloc[:, 50]

# Split dataset in training and test datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print(clf.score(X_test, y_test))
# Out:
# 0.7657148622742408

# %%
target_names = ["not viral", "viral"]

# Calculate classification report
from sklearn.metrics import classification_report
predictions = clf.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#   not viral       0.95      0.79      0.86      9359
#       viral       0.09      0.37      0.15       552
#
# avg / total       0.91      0.77      0.82      9911
